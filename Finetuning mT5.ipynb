# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 249 kB 12.9 MB/s
# ...
#      |████████████████████████████████| 9.1 MB 69.2 MB/s
# ...
#      |████████████████████████████████| 365 kB 74.2 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 62.0 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 48.0 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 45.2 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 63.4 MB/s
# ...
#      |████████████████████████████████| 120 kB 59.4 MB/s
# ...
#      |████████████████████████████████| 157 kB 72.6 MB/s
# ...
#      |████████████████████████████████| 181 kB 79.8 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 157 kB 71.3 MB/s
# ...
#      |████████████████████████████████| 157 kB 80.9 MB/s
# ...
#      |████████████████████████████████| 157 kB 82.5 MB/s
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Preprocessing Procesing mt5 input dataset

# %%
dataset_comb =  pd.read_csv('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/datasets/Combined(PAWSX + Tapaco)/dataset_comb.csv')

# %%
dataset_comb.rename(columns = {'Text':'input_text', 'Paraphrase':'target_text', 'lan':'prefix'}, inplace = True)

# %%
dataset_comb.head()
# Out:
#                                           input_text  \
# 0                  El gato se come al pequeño ratón.
# 1  Fue escrito por Nancy Steen y Neil Thompson, d...
# 2                          Where is the coffee shop?
# 3                            Everybody was startled.
# 4  Navegó por Sydney y llegó a Río de Janeiro el ...
#
#                                          target_text prefix
# 0                         El gato se comió al ratón.     es
# 1  Dirigida por Paul Krasny, escrita por Nancy St...     es
# 2                            Where is the cafeteria?     en
# 3                             Everybody was stunned.     en
# 4  Navegó por Sydney y llegó el 14 de septiembre ...     es

# %%
dataset_comb_tr, dataset_comb_test = train_test_split(dataset_comb, test_size=0.2)
dataset_comb_test, dataset_comb_val = train_test_split(dataset_comb_test, test_size=0.5)

# %%
dataset_comb_tr = dataset_comb_tr.reset_index(drop=True)
dataset_comb_test = dataset_comb_test.reset_index(drop=True)
dataset_comb_val = dataset_comb_test.reset_index(drop=True)

# %%
print(len(dataset_comb_tr), len(dataset_comb_test), len(dataset_comb_val))
# Out:
# 161225 20153 20153

# %%
dataset_comb_tr
# Out:
#                                                input_text  \
# 0                                 Casi no nos queda agua.
# 1                                Ellos te están buscando.
# 2       Natália Falavigna da Silva ( born May 9 , 1984...
# 3                                      I went to see Tom.
# 4       According to the U.S. Census Bureau , the coun...
# ...                                                   ...
# 161220                                  Tom estaba mejor.
# 161221          El deporte que más me gusta es el fútbol.
# 161222                             We got along famously.
# 161223                      Tom gave Mary a diamond ring.
# 161224                              Ojalá fuera más alto.
#
#                                               target_text prefix
# 0                            Apenas tenemos algo de agua.     es
# 1                                      Os están buscando.     es
# 2       Natália Falavigna da Silva ( born May 9 , 1984...     en
# ...

# %%
dataset_comb.to_csv('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/datasets/Combined(PAWSX + Tapaco)/mt5_input/dataset_comb_input.csv', index = False)
dataset_comb_tr.to_csv('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/datasets/Combined(PAWSX + Tapaco)/mt5_input/dataset_comb_tr.csv', index = False)
dataset_comb_test.to_csv('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/datasets/Combined(PAWSX + Tapaco)/mt5_input/dataset_comb_test.csv', index = False)
dataset_comb_val.to_csv('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/datasets/Combined(PAWSX + Tapaco)/mt5_input/dataset_comb_val.csv', index = False)

# %% [markdown]
# # TRAINING mt5-base es

# %%
  dataset_comb_tr = pd.read_csv('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/datasets/Combined(PAWSX + Tapaco)/mt5_input/dataset_comb_tr.csv').astype(str)
  dataset_comb_test = pd.read_csv('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/datasets/Combined(PAWSX + Tapaco)/mt5_input/dataset_comb_test.csv').astype(str)
dataset_comb_val = pd.read_csv('/content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/datasets/Combined(PAWSX + Tapaco)/mt5_input/dataset_comb_val.csv').astype(str)

# %%
  dataset_comb_tr
# Out:
#                                                input_text  \
# 0                                 Casi no nos queda agua.
# 1                                Ellos te están buscando.
# 2       Natália Falavigna da Silva ( born May 9 , 1984...
# 3                                      I went to see Tom.
# 4       According to the U.S. Census Bureau , the coun...
# ...                                                   ...
# 161220                                  Tom estaba mejor.
# 161221          El deporte que más me gusta es el fútbol.
# 161222                             We got along famously.
# 161223                      Tom gave Mary a diamond ring.
# 161224                              Ojalá fuera más alto.
#
#                                               target_text prefix
# 0                            Apenas tenemos algo de agua.     es
# 1                                      Os están buscando.     es
# 2       Natália Falavigna da Silva ( born May 9 , 1984...     en
# ...

# %%
  dataset_comb_tr[dataset_comb_tr.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [input_text, target_text, prefix]
# Index: []

# %%
  dataset_comb_tr = dataset_comb_tr[dataset_comb_tr['prefix'] == 'en']
  dataset_comb_test = dataset_comb_test[dataset_comb_test['prefix'] == 'en']
  dataset_comb_val = dataset_comb_val[dataset_comb_val['prefix'] == 'en']

# %%
print(len(dataset_comb_tr), len(dataset_comb_test), len(dataset_comb_val))
# Out:
# 94324 11929 11929

# %%
dataset_comb_tr.loc[dataset_comb_tr['prefix'] == 'es', ['prefix']] = 'rephrase'
dataset_comb_test.loc[dataset_comb_test['prefix'] == 'es', ['prefix']] = 'rephrase'
dataset_comb_val.loc[dataset_comb_val['prefix'] == 'es', ['prefix']] = 'rephrase'
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
dataset_comb_test
# Out:
#                                               input_text  \
# 2      The Chapel and Hall were both fully funded by ...
# 3                                     This isn't my key.
# 4                                     He is a biologist.
# 5           I haven't read all the books on the shelves.
# 6                    He is able to run faster than I am.
# ...                                                  ...
# 20146  Many provinces and states organize regional an...
# 20148                           He still has not called.
# 20149                        We'll certainly invite Tom.
# 20151                             Tom called the police.
# 20152                  Tom is too afraid to do that now.
#
#                                              target_text prefix
# 2      The chapel and the room were both fully funded...     en
# 3                                  This key is not mine.     en
# 4                                      He's a biologist.     en
# ...

# %% [markdown]
# # Train run mT5-base es hyp-finetuned

# %%
import logging
import pandas as pd
from simpletransformers.t5 import T5Model, T5Args
import sklearn

# %%
model_args = T5Args()
model_args.max_seq_length = 128
model_args.train_batch_size = 8
model_args.eval_batch_size = 8
model_args.num_train_epochs = 1
model_args.warmup_ratio = 0.06
model_args.learning_rate = 1e-4
model_args.early_stopping_patience = 2
model_args.use_early_stopping = True
model_args.evaluate_during_training = True
model_args.evaluate_during_training_steps = 2000
model_args.evaluate_during_training_verbose = True
model_args.use_multiprocessing = False
model_args.fp16 = False
model_args.save_steps = -1
model_args.save_eval_checkpoints = False
model_args.no_cache = True
model_args.preprocess_inputs = True
model_args.reprocess_input_data = True
model_args.overwrite_output_dir = True
model_args.num_return_sequences = 1
model_args.wandb_project = "mT5-base en hyp-finetuned"

# by default AdamW, weight decay with L2 penalty, and  lr scheduler:linear schedule with warmup

# %%
model = T5Model("mt5", "google/mt5-base", args=model_args, output_dir='/content/drive/MyDrive/working_directory/tfm/Distilled_mt5_finetuning/mt5_outputs')
# Out:
# Downloading:   0%|          | 0.00/702 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.17G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/376 [00:00<?, ?B/s]

# %%
model.train_model(dataset_comb_tr, eval_data=dataset_comb_val )
# Out:
#   0%|          | 0/66783 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3557: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and the tokenizer under the `as_target_tokenizer` context manager to prepare
# your targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, ...)
# with tokenizer.as_target_tokenizer():
#     labels = tokenizer(tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
#   warnings.warn(formatted_warning, FutureWarning)
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
# !cp -r outputs /content/drive/MyDrive/working_directory/tfm/Distilled_GPT2_finetuning/mt5_outputs/outputs_es

# %% [markdown]
# # Fine-tuning hyperparameters mT5-base en with simple transformers using Sweep

# %%
import logging
import pandas as pd
from simpletransformers.t5 import T5Model, T5Args
import sklearn
import wandb

logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# %%
sweep_config = {
    "name" : "mt5-sweep",
    "method": "bayes",  # grid, random, bayes
    "metric": {"name": "train_loss", "goal": "minimize"},
    "parameters": {
        "num_train_epochs": {"values": [1, 3, 5]},
        "learning_rate": {"min": 1e-5, "max": 1e-4},
        "warmup_ratio": {"values": [0.06, 0.2, 0.3]}
    },
}

# %%
sweep_id = wandb.sweep(sweep_config, project="test2")
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Create sweep with ID: z0sa49ha
# Sweep URL: https://wandb.ai/lxrandom/test2/sweeps/z0sa49ha

# %%
model_args = T5Args()
model_args.max_seq_length = 128
model_args.train_batch_size = 8
model_args.eval_batch_size = 8
#model_args.num_train_epochs = 1
model_args.use_early_stopping = True
model_args.evaluate_during_training = True
model_args.evaluate_during_training_steps = 30000
model_args.use_multiprocessing = False
model_args.fp16 = False
model_args.save_steps = -1
model_args.save_eval_checkpoints = False
model_args.no_cache = True
model_args.reprocess_input_data = True
model_args.overwrite_output_dir = True
model_args.preprocess_inputs = True
model_args.num_return_sequences = 1
model_args.wandb_project = "test2"

# %%
def train():
    # Initialize a new wandb run
    wandb.init()

    # Create a TransformerModel
    model = T5Model("mt5", "google/mt5-base",  args=model_args, sweep_config=wandb.config)
    # Train the model
    model.train_model(dataset_comb_tr, eval_data=dataset_comb_val)

    # Evaluate the model
    model.eval_model(dataset_comb_test)

    # Sync wandb
    wandb.join()

# %%
# !rm -rf wandb/
# !rm -rf runs/
# !rm -rf outputs/

# %%
wandb.agent(sweep_id, train)
